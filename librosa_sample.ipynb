# %%
% config InlineBackend.figure_format='retina'
# audioファイルを読み込んで可視化
import librosa, librosa.display
import matplotlib.pyplot as plt
# %time sound, fs = librosa.audio.load('UrbanSound8K/audio/fold1/101415-3-0-2.wav')
plt.figure()
librosa.display.waveplot(sound, sr=fs)
plt.show()
# Out:
# CPU times: user 219 ms, sys: 4.36 ms, total: 223 ms
# Wall time: 255 ms
